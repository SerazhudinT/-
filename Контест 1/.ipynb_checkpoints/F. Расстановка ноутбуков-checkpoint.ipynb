# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a, b, c, d = map(int, input().split())

s1 = ((a + c) * max(b, d), ((a + c), max(b, d)))
s2 = ((a + d) * max(b, c), ((a + d), max(b, c)))
s3 = ((b + c) * max(a, d), ((b + c), max(a, d)))
s4 = ((b + d) * max(a, c), ((b + d), max(a, c)))

print(*min(s1, s2, s3, s4)[1])
