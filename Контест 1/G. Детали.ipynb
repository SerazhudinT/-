# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
N, K, M = map(int, input().split())

number = 0

while N // K > 0 and K // M > 0:
    numberK = N // K
    N %= K
    
    number += numberK * (K // M)
    N += numberK * (K % M)
    
print(number)
