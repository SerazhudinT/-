# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
with open('input.txt') as fin:
    N = int(fin.readline())
    
    coordList = []
    for i in range(N):
        coordList.append(tuple(map(int, fin.readline().split())))
    
    count = 0
    for i in range(N):
        
        distDict = {}
        for j in range(N):
            if j == i:
                continue
                
            dist = (coordList[i][0] - coordList[j][0])**2 + (coordList[i][1] - coordList[j][1])**2
            
            distDict[dist] = distDict.get(dist, 0) + 1
            
        print(distDict)
            
    print(count)
# Out:
# {2: 1, 1: 2}
# {2: 1, 1: 2}
# {1: 2, 2: 1}
# {1: 2, 2: 1}
# 0

# %%
coordList
# Out:
# [(0, 0), (1, 1), (1, 0), (0, 1)]

# %%
distSet
# Out:
# {1, 2}
