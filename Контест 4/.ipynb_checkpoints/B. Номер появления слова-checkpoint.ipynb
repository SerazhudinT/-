# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('input.txt') as fin:
    dct = {}
    lst = []
    
    for string in fin:
        string = string.split()
        
        for word in string:
            dct[word] = dct.get(word, -1) + 1
            
            lst.append(dct[word])
            
    print(*lst)
