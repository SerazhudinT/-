# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
with open('input.txt') as fin:
    N = int(fin.readline())
        
    dct = {}
        
    for i in range(N):
        word1, word2 = fin.readline().split()

        dct[word1] = word2
        dct[word2] = word1
    
    word = fin.readline().strip()
    
    print(dct[word])
