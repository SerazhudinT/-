# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
with open('input.txt') as fin:
    buttons = set(fin.readline().split())  
    N = set(fin.readline().strip())
            
    print(len(N - buttons))
