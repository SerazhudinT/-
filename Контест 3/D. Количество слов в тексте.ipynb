# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
with open('input.txt') as fin:
    arrSet = set()
    
    for elem in fin:
        arrSet |= set(elem.split())

    print(len(arrSet))
