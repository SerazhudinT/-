# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
N = int(input())
arr = list(map(int, input().split()))
x = int(input())

minErr, minValue = abs(arr[0] - x), arr[0]

for elem in arr:
    if minErr > abs(elem - x):
        minErr, minValue = abs(elem - x), elem
    
print(minValue)
