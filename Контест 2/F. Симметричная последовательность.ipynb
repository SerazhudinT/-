# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def isPalindrom(arr):
    return arr == arr[::-1]


N = int(input())
arr = list(map(int, input().split()))

i = 0
while not isPalindrom(arr[i:]):
    i += 1

print(i)
if i != 0:
    print(*arr[:i][::-1])
