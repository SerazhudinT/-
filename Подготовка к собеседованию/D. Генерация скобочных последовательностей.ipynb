# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
def generate(res, left, right, n):
    if len(res) == 2 * n:
        print(res)
        return
    
    if left < n:
        generate(res + '(', left + 1, right, n)
    
    if left > right:
        generate(res + ')', left, right + 1, n)


n = int(input())

generate('', 0, 0, n)
# Out:
# 3
# ((()))
# (()())
# (())()
# ()(())
# ()()()
