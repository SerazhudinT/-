# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
with open('input.txt') as fin:
    J = fin.readline().strip()
    S = fin.readline().strip()
    
    count = 0
    for char in S:
        if char in J:
            count += 1
    
    print(count)
# Out:
# 4
