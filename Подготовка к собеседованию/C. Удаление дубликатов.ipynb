# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
with open('input.txt') as fin:
    N = int(fin.readline())
    
    for i in range(N):
        cur = int(fin.readline())
    
        if i == 0 or i > 0 and cur != prev:
            print(cur)
            prev = cur
# Out:
# 2
# 4
# 8
